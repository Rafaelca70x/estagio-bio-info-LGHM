# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
eigval = pd.read_csv('cftr_eigenval.txt',header=None, names=['Eigenval'])
eigvec = pd.read_csv('cftr_eigenvec.txt', sep=' ', header=None).drop(columns=[0,1])
eigenval = eigval.to_numpy(dtype='float32')
eigenvec = eigvec.to_numpy(dtype='float32')

# %%
eigenval = eigenval.reshape(-1)

# %%
plt.plot(eigenval, 'ko')

# %%
pcNop = eigenvec[:,0:2].T
